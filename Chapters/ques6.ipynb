# %%
import pandas as pd

data = pd.read_csv('weather.csv')
mean_precipitation_by_state = data.groupby('Station.State')['Data.Precipitation'].mean()
mean_precipitation_by_state.head()
# Out:
# Station.State
# Alabama       0.776179
# Alaska        0.566126
# Arizona       0.162566
# Arkansas      0.603711
# California    0.323774
# Name: Data.Precipitation, dtype: float64

# %%
data.head()
data['Date.Full'].ffill(inplace=True)
data['Date.Full']
# Out:
# 0        2016-01-03
# 1        2016-01-03
# 2        2016-01-03
# 3        2016-01-03
# 4        2016-01-03
#             ...
# 16738    2017-01-01
# 16739    2017-01-01
# 16740    2017-01-01
# 16741    2017-01-01
# 16742    2017-01-01
# Name: Date.Full, Length: 16743, dtype: object

# %%
data['Date'] = pd.to_datetime(data['Date.Year'].astype(str) + '-' + data['Date.Month'].astype(str))
data
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
# Group by 'Station.State' and 'Station.City', calculate mean 'Data.Temperature.Avg Temp' and sort within groups
sorted_group = data.groupby(['Station.State', 'Station.City'])['Data.Temperature.Avg Temp'].mean().reset_index()
sorted_group = sorted_group.sort_values(['Station.State', 'Data.Temperature.Avg Temp'], ascending=[True, False])
print(sorted_group)
# Out:
#     Station.State Station.City  Data.Temperature.Avg Temp
# 2         Alabama       Mobile                  68.301887
# 3         Alabama   Montgomery                  68.056604
# 0         Alabama   Birmingham                  65.452830
# 1         Alabama   Huntsville                  64.301887
# 13         Alaska     Gustavus                  60.000000
# ..            ...          ...                        ...
# 314       Wyoming     Cheyenne                  48.207547
# 317       Wyoming     Sheridan                  47.660377
# 313       Wyoming       Casper                  46.547170
# 315       Wyoming       Lander                  46.150943
# 316       Wyoming      Rawlins                  43.886792
#
# [318 rows x 3 columns]

# %%
num_bins = 5
data['Temperature_Bin'] = pd.cut(data['Data.Temperature.Avg Temp'], bins=num_bins, labels=False)
grouped_bins = data.groupby('Temperature_Bin')
for group_name, group_data in grouped_bins:
    print(f"Bin {group_name}:")
    print(group_data)
# Out:
# Bin 0:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 64                   0.00  2016-01-03           1             3       2016
# 338                  0.00  2016-01-10           1            10       2016
# 663                  0.03  2016-01-17           1            17       2016
# 777                  0.10  2016-01-17           1            17       2016
# 844                  0.27  2016-01-17           1            17       2016
# ...                   ...         ...         ...           ...        ...
# 16007                0.01  2016-12-18          12            18       2016
# 16009                0.02  2016-12-18          12            18       2016
# 16010                0.00  2016-12-18          12            18       2016
# 16043                0.29  2016-12-18          12            18       2016
# 16133                0.00  2016-12-25          12            25       2016
#
# ...
